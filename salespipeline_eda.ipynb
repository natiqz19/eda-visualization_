# %%
import pandas as pd # data manipulation
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil, floor

# %%
df = pd.read_csv('WA_Fn-UseC_-Sales-Win-Loss.csv')
df.head()
# Out:
#    Index  Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0      1             1641984  Exterior Accessories         Car Accessories
# 1      2             1658010  Exterior Accessories         Car Accessories
# 2      3             1674737      Motorcycle Parts  Performance & Non-auto
# 3      4             1675224         Shelters & RV  Performance & Non-auto
# 4      5             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage  \
# 0  Northwest    Fields Sales                           76
# 1    Pacific        Reseller                           63
# 2    Pacific        Reseller                           24
# 3    Midwest        Reseller                           16
# 4    Pacific        Reseller                           69
#
#    Sales Stage Change Count Opportunity Result  \
# 0                        13                Won
# 1                         2               Loss
# 2                         7                Won
# 3                         5               Loss
# 4                        11               Loss
#
#    Total Days Identified Through Closing  \
# 0                                    104
# 1                                    163
# 2                                     82
# 3                                    124
# 4                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years Competitor Type  \
# 0                                   0         Unknown
# 1                                   0         Unknown
# 2                                   0         Unknown
# 3                                   0           Known
# 4                                   0         Unknown
#
#    Ratio Days Identified To Total Days  Ratio Days Validated To Total Days  \
# 0                              0.69636                            0.113985
# 1                              0.00000                            1.000000
# 2                              1.00000                            0.000000
# 3                              1.00000                            0.000000
# 4                              0.00000                            0.141125
#
#    Ratio Days Qualified To Total Days  Deal Size Category
# 0                            0.154215                   1
# 1                            0.000000                   1
# 2                            0.000000                   1
# 3                            0.000000                   1
# 4                            0.000000                   4

# %%
# Defining function to set figure size
def figure(a,b):
    sns.set(rc={'figure.figsize':(a,b)})

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### Display

# %%
df_string = df.loc[:,df.dtypes == 'object']
df_string.head()
# Out:
#       Supplies Subgroup          Supplies Group     Region Route To Market  \
# 0  Exterior Accessories         Car Accessories  Northwest    Fields Sales
# 1  Exterior Accessories         Car Accessories    Pacific        Reseller
# 2      Motorcycle Parts  Performance & Non-auto    Pacific        Reseller
# 3         Shelters & RV  Performance & Non-auto    Midwest        Reseller
# 4  Exterior Accessories         Car Accessories    Pacific        Reseller
#
#   Opportunity Result Competitor Type
# 0                Won         Unknown
# 1               Loss         Unknown
# 2                Won         Unknown
# 3               Loss           Known
# 4               Loss         Unknown

# %% [markdown]
# ### Display

# %%
print(df_string.columns.tolist())
# Out:
# ['Supplies Subgroup', 'Supplies Group', 'Region', 'Route To Market', 'Opportunity Result', 'Competitor Type']

# %% [markdown]
# ### Display

# %%
figure(15,10)

plt_cols = 3                                                           # Customized no. of columns in subplot
plt_rows = ceil(len(df_string.columns)/plt_cols)                       # Set the no. of rows in subplot by dividing: 
                                                                       #  roundup(no. of variables / no. of columns)
    
fig, axes = plt.subplots(plt_rows,plt_cols)
fig.suptitle("Countplots of Categorical Variables \n (x-axis: Variable) \n (y-axis: Count of samples)", 
             fontsize="x-large")
axes = axes.ravel()

for i in range(0, len(df_string.columns)):
    sns.countplot(df_string.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
    axes[i].set_title('Countplot of ' + df_string.columns[i], size=15) # Set title of every subplot
    axes[i].tick_params(axis='x', labelrotation=90, pad=0)             # Rotate x-axis of every subplot
    axes[i].set_xlabel('')                                             # Turn off subplots' x-axis titles for tidiness
fig.tight_layout(rect=[0, 0, 1, 0.88])                                 # Adjust tight_layout to accommodate suptitle

# %% [markdown]
# ## Numerical variables

# %% [markdown]
# ### Display

# %%
df_numeric0 = df.loc[:, df.dtypes!='object']
df_numeric0.head()
# Out:
#    Index  Opportunity Number  Elapsed Days In Sales Stage  \
# 0      1             1641984                           76
# 1      2             1658010                           63
# 2      3             1674737                           24
# 3      4             1675224                           16
# 4      5             1689785                           69
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# 1                         2                                    163
# 2                         7                                     82
# 3                         5                                    124
# 4                        11                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years  Ratio Days Identified To Total Days  \
# 0                                   0                              0.69636
# 1                                   0                              0.00000
# 2                                   0                              1.00000
# 3                                   0                              1.00000
# 4                                   0                              0.00000
#
#    Ratio Days Validated To Total Days  Ratio Days Qualified To Total Days  \
# 0                            0.113985                            0.154215
# 1                            1.000000                            0.000000
# 2                            0.000000                            0.000000
# 3                            0.000000                            0.000000
# 4                            0.141125                            0.000000
#
#    Deal Size Category
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   4

# %%
df_numeric0 = df.loc[:, df.dtypes!='object']

# Check presence of Index / index 
#  and drop those columns
id_cols = ['Index', 'index']
df_numeric = df_numeric0.loc[:, ~df_numeric0.columns.isin(id_cols)]
    
df_numeric.head()
# Out:
#    Opportunity Number  Elapsed Days In Sales Stage  Sales Stage Change Count  \
# 0             1641984                           76                        13
# 1             1658010                           63                         2
# 2             1674737                           24                         7
# 3             1675224                           16                         5
# 4             1689785                           69                        11
#
#    Total Days Identified Through Closing  \
# 0                                    104
# 1                                    163
# 2                                     82
# 3                                    124
# 4                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years  Ratio Days Identified To Total Days  \
# 0                                   0                              0.69636
# 1                                   0                              0.00000
# 2                                   0                              1.00000
# 3                                   0                              1.00000
# 4                                   0                              0.00000
#
#    Ratio Days Validated To Total Days  Ratio Days Qualified To Total Days  \
# 0                            0.113985                            0.154215
# 1                            1.000000                            0.000000
# 2                            0.000000                            0.000000
# 3                            0.000000                            0.000000
# 4                            0.141125                            0.000000
#
#    Deal Size Category
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   4

# %%
# Check presence of Index / index 
#  columns to be removed
id_col = ['Index', 'index']

for i in df_numeric.columns:
    if i in id_col:
        df_numeric = df_numeric.drop(labels='Index',axis=1)
    print(i)
# Out:
# Opportunity Number
# Elapsed Days In Sales Stage
# Sales Stage Change Count
# Total Days Identified Through Closing
# Total Days Identified Through Qualified
# Opportunity Amount USD
# Client Size By Revenue
# Client Size By Employee Count
# Revenue From Client Past Two Years
# Ratio Days Identified To Total Days
# Ratio Days Validated To Total Days
# Ratio Days Qualified To Total Days
# Deal Size Category

# %%
figure(15,10)

plt_cols = 3                                                           # Customized no. of columns in subplot
plt_rows = ceil(len(df_numeric.columns)/plt_cols)                       # Set the no. of rows in subplot by dividing: 
                                                                       #  roundup(no. of variables / no. of columns)
    
fig, axes = plt.subplots(plt_rows,plt_cols)
fig.suptitle("Distribution Plots of Numerical Variables \n (x-axis: Variable) \n (y-axis: Distribution proportion)", 
             fontsize="x-large")

axes = axes.ravel()

for i in range(0, len(df_numeric.columns)):
    sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
    axes[i].set_title(df_numeric.columns[i], size=15) # Set title of every subplot
    axes[i].tick_params(axis='x', labelrotation=90, pad=0)             # Rotate x-axis of every subplot
    axes[i].set_xlabel('')                                             # Turn off subplots' x-axis titles for tidiness
fig.tight_layout(rect=[0, 0, 1, 0.88])                                 # Adjust tight_layout to accommodate suptitle
# Out:
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3696395071.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i], ax=axes[i])                     # Plot countplot for each categorical variable

# %%
# fig, axs = plt.subplots(2,5, figsize=(15, 6), facecolor='w', edgecolor='k')
# fig.subplots_adjust(hspace = .5, wspace=.001)

# axs = axs.ravel()

# for i in range(10):
#     axs[i].contourf(np.random.rand(10,10),5,cmap=plt.cm.Oranges)
#     axs[i].set_title(str(250+i))

# %%
## **************************************** ##

# %% [markdown]
# ## Original Code

# %%
figure(15,8)

plt_cols = 3 # set the no. of columns in subplot
# set the no. of rows in subplot by dividing no. of cols and round up
plt_rows = ceil((len(df_string.columns)+1)/plt_cols)  

i=0
for i in range(0, len(df_string.columns), 1):
    plt.subplot(plt_rows,plt_cols,i+1)
    sns.countplot(df_string.iloc[:,i])
    plt.title('Countplot of ' + df_string.columns[i])
    plt.xticks(rotation=45)
    plt.subplots_adjust(bottom=0.01)
    plt.tick_params(labelsize=8, pad=0)
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=2, 
                    wspace=0.4, 
                    hspace=0.4)
    i += 1

# %%
plt.show()

# %%
figure(15,10)

plt_cols = 3 # set the no. of columns in subplot
# set the no. of rows in subplot by dividing no. of cols and round up
plt_rows = ceil((len(df_numeric.columns)+1)/plt_cols)  

i=0
for i in range(0, len(df_numeric.columns), 1):
    plt.subplot(plt_rows,plt_cols,i+1)
    sns.distplot(df_numeric.iloc[:,i])
    plt.title('Distplot of ' + df_numeric.columns[i])
    plt.xticks(rotation=45)
    plt.subplots_adjust(bottom=0.01)
    plt.tick_params(labelsize=8)
    i += 1
# Out:
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])
# C:\Users\atirazmi\AppData\Local\Temp\ipykernel_8612\3790295403.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_numeric.iloc[:,i])

# %%
figure(15,10)

plt_cols = 3 # set the no. of columns in subplot
# set the no. of rows in subplot by dividing no. of cols and round up
plt_rows = ceil((len(df_numeric.columns)+1)/plt_cols)  

i=0
for i in range(0, len(df_numeric.columns), 1):
    plt.subplot(plt_rows,plt_cols,i+1)
    sns.histplot(df_numeric.iloc[:,i], kde=True)
    plt.title('Distplot of ' + df_numeric.columns[i])
    plt.xticks(rotation=45)
    plt.subplots_adjust(bottom=0.01)
    plt.tick_params(labelsize=8)
    i += 1

# %%
import streamlit as st # web app

# %%
st.title("Data Visualization Dashboard")
# Out:
# 2024-01-22 14:07:52.765
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\atirazmi\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
